# %%
# %run constants.ipynb

# %%
# Load the arguments
with open(ARGUMENTS_FILENAME, "r") as fid:
    arguments = json.load(fid)
    
df = pd.read_csv(arguments["dataframe_outfile"])
df["date clean"] = pd.to_datetime(df["date clean"])
df.set_index("date clean", inplace=True)
df.sort_index(inplace=True)

# %% [markdown]
# ## Cervical mucus charting

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html
symbol_colors = {
    "B": "brown",  # brown bleeding
    "S": "pink",  # spotting
    "L": "salmon",  # light
    "M": "tomato",  # medium
    "H": "red",  # heavy
    "EL": "cornflowerblue",  # EL, mucus with some estrogen
    "ES": "royalblue",  # ES, mucus with high estrogen
    "G": "gray",  # dry, high in progesterone
    "U": "gold",  # unknown
}

# Create dataset where we have cycle data, so we can always pivot on day
subset = df[df["day of cycle"].notnull()]
subset["day of cycle"] = subset["day of cycle"].astype(int)

# %%
def lookup_color(symbol_col):
    return [
        f"background-color: {symbol_colors.get(symbol, 'white')}; color: white; font-weight: bold;"
        for symbol in symbol_col
    ]

table = subset[subset["valid_cycle"]].pivot(
    index="nth_cycle",
    columns="day of cycle",
    values="symbol",
)

styled_table = table.style.apply(lookup_color)
styled_table
# Out:
# <style  type="text/css" >
# #T_1ec07_row0_col0,#T_1ec07_row0_col2,#T_1ec07_row0_col3,#T_1ec07_row1_col0,#T_1ec07_row1_col1{
#             background-color:  salmon;
#              color:  white;
#              font-weight:  bold;
#         }#T_1ec07_row0_col1{
#             background-color:  tomato;
#              color:  white;
#              font-weight:  bold;
#         }#T_1ec07_row0_col4,#T_1ec07_row0_col5,#T_1ec07_row0_col25,#T_1ec07_row1_col2,#T_1ec07_row1_col3,#T_1ec07_row1_col4{
#             background-color:  pink;
#              color:  white;
#              font-weight:  bold;
#         }#T_1ec07_row0_col6,#T_1ec07_row0_col7,#T_1ec07_row0_col8,#T_1ec07_row0_col9,#T_1ec07_row0_col10,#T_1ec07_row0_col11,#T_1ec07_row0_col12,#T_1ec07_row0_col13,#T_1ec07_row0_col14,#T_1ec07_row0_col15,#T_1ec07_row1_col10,#T_1ec07_row1_col11,#T_1ec07_row1_col12,#T_1ec07_row1_col13,#T_1ec07_row1_col15,#T_1ec07_row1_col16,#T_1ec07_row1_col17,#T_1ec07_row1_col18{
#             background-color:  royalblue;
#              color:  white;
#              font-weight:  bold;
#         }#T_1ec07_row0_col16,#T_1ec07_row0_col17,#T_1ec07_row0_col18,#T_1ec07_row0_col19,#T_1ec07_row0_col20,#T_1ec07_row0_col21,#T_1ec07_row0_col22,#T_1ec07_row0_col23,#T_1ec07_row0_col24,#T_1ec07_row1_col5,#T_1ec07_row1_col6,#T_1ec07_row1_col8,#T_1ec07_row1_col9,#T_1ec07_row1_col14,#T_1ec07_row1_col19,#T_1ec07_row1_col20,#T_1ec07_row1_col21,#T_1ec07_row1_col22,#T_1ec07_row1_col23{
#             background-color:  gray;
#              color:  white;
#              font-weight:  bold;
#         }#T_1ec07_row1_col7{
#             background-color:  gold;
#              color:  white;
#              font-weight:  bold;
#         }#T_1ec07_row1_col24,#T_1ec07_row1_col25{
#             background-color:  white;
#              color:  white;
#              font-weight:  bold;
#         }</style><table id="T_1ec07_" ><thead>    <tr>        <th class="index_name level0" >day of cycle</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>        <th class="col_heading level0 col5" >6</th>        <th class="col_heading level0 col6" >7</th>        <th class="col_heading level0 col7" >8</th>        <th class="col_heading level0 col8" >9</th>        <th class="col_heading level0 col9" >10</th>        <th class="col_heading level0 col10" >11</th>        <th class="col_heading level0 col11" >12</th>        <th class="col_heading level0 col12" >13</th>        <th class="col_heading level0 col13" >14</th>        <th class="col_heading level0 col14" >15</th>        <th class="col_heading level0 col15" >16</th>        <th class="col_heading level0 col16" >17</th>        <th class="col_heading level0 col17" >18</th>        <th class="col_heading level0 col18" >19</th>        <th class="col_heading level0 col19" >20</th>        <th class="col_heading level0 col20" >21</th>        <th class="col_heading level0 col21" >22</th>        <th class="col_heading level0 col22" >23</th>        <th class="col_heading level0 col23" >24</th>        <th class="col_heading level0 col24" >25</th>        <th class="col_heading level0 col25" >26</th>    </tr>    <tr>        <th class="index_name level0" >nth_cycle</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ec07_level0_row0" class="row_heading level0 row0" >1.0</th>
#                         <td id="T_1ec07_row0_col0" class="data row0 col0" >L</td>
#                         <td id="T_1ec07_row0_col1" class="data row0 col1" >M</td>
#                         <td id="T_1ec07_row0_col2" class="data row0 col2" >L</td>
#                         <td id="T_1ec07_row0_col3" class="data row0 col3" >L</td>
#                         <td id="T_1ec07_row0_col4" class="data row0 col4" >S</td>
#                         <td id="T_1ec07_row0_col5" class="data row0 col5" >S</td>
#                         <td id="T_1ec07_row0_col6" class="data row0 col6" >ES</td>
#                         <td id="T_1ec07_row0_col7" class="data row0 col7" >ES</td>
#                         <td id="T_1ec07_row0_col8" class="data row0 col8" >ES</td>
#                         <td id="T_1ec07_row0_col9" class="data row0 col9" >ES</td>
#                         <td id="T_1ec07_row0_col10" class="data row0 col10" >ES</td>
#                         <td id="T_1ec07_row0_col11" class="data row0 col11" >ES</td>
#                         <td id="T_1ec07_row0_col12" class="data row0 col12" >ES</td>
#                         <td id="T_1ec07_row0_col13" class="data row0 col13" >ES</td>
#                         <td id="T_1ec07_row0_col14" class="data row0 col14" >ES</td>
#                         <td id="T_1ec07_row0_col15" class="data row0 col15" >ES</td>
#                         <td id="T_1ec07_row0_col16" class="data row0 col16" >G</td>
#                         <td id="T_1ec07_row0_col17" class="data row0 col17" >G</td>
#                         <td id="T_1ec07_row0_col18" class="data row0 col18" >G</td>
#                         <td id="T_1ec07_row0_col19" class="data row0 col19" >G</td>
#                         <td id="T_1ec07_row0_col20" class="data row0 col20" >G</td>
#                         <td id="T_1ec07_row0_col21" class="data row0 col21" >G</td>
#                         <td id="T_1ec07_row0_col22" class="data row0 col22" >G</td>
#                         <td id="T_1ec07_row0_col23" class="data row0 col23" >G</td>
#                         <td id="T_1ec07_row0_col24" class="data row0 col24" >G</td>
#                         <td id="T_1ec07_row0_col25" class="data row0 col25" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_1ec07_level0_row1" class="row_heading level0 row1" >2.0</th>
#                         <td id="T_1ec07_row1_col0" class="data row1 col0" >L</td>
#                         <td id="T_1ec07_row1_col1" class="data row1 col1" >L</td>
#                         <td id="T_1ec07_row1_col2" class="data row1 col2" >S</td>
#                         <td id="T_1ec07_row1_col3" class="data row1 col3" >S</td>
#                         <td id="T_1ec07_row1_col4" class="data row1 col4" >S</td>
#                         <td id="T_1ec07_row1_col5" class="data row1 col5" >G</td>
#                         <td id="T_1ec07_row1_col6" class="data row1 col6" >G</td>
#                         <td id="T_1ec07_row1_col7" class="data row1 col7" >U</td>
#                         <td id="T_1ec07_row1_col8" class="data row1 col8" >G</td>
#                         <td id="T_1ec07_row1_col9" class="data row1 col9" >G</td>
#                         <td id="T_1ec07_row1_col10" class="data row1 col10" >ES</td>
#                         <td id="T_1ec07_row1_col11" class="data row1 col11" >ES</td>
#                         <td id="T_1ec07_row1_col12" class="data row1 col12" >ES</td>
#                         <td id="T_1ec07_row1_col13" class="data row1 col13" >ES</td>
#                         <td id="T_1ec07_row1_col14" class="data row1 col14" >G</td>
#                         <td id="T_1ec07_row1_col15" class="data row1 col15" >ES</td>
#                         <td id="T_1ec07_row1_col16"

# %%
# Note: this requires installing an old version of Pillow: Pillow==9.0.0
import dataframe_image as dfi

date = datetime.datetime.now().strftime("%Y-%m-%d")
dfi.export(styled_table, f"{arguments['output_directory']}/charting_{date}.png", dpi=400)

# %% [markdown]
# ## Analysis of symptoms over time

# %% [markdown]
# ### Fatigue, a categorical variable

# %%
def plot_categorical_rate(metric, days_mean, nan_is_no=False):
    possible_values = [
        "ok",  # e.g. for fatigue
        "no",
        "yes",
        "extreme",
    ]

    for possible_value in possible_values:
        df[f"{metric}_{possible_value}"] = (df[metric] == possible_value).astype(int)
        # assume no value means "no", if desired
        if nan_is_no and possible_value == "no":
            df.loc[df[metric].isnull(), f"{metric}_{possible_value}"] = 1

    rate_metrics = [
        f"{metric}_{possible_value}"
        for possible_value in possible_values
    ]

    fig, ax = plt.subplots(figsize=(12, 8))
    for rate_metric in rate_metrics:
        if df[rate_metric].mean() == 0:
            continue

        plt.plot(
            df[rate_metric].rolling(f"{days_mean}D").mean() * 100,
            label=rate_metric.replace(f"{metric}_", ""),
        )
        fig.autofmt_xdate()

    plt.legend(title=metric.title())
    plt.title(f"{metric.title()} frequency")
    plt.ylabel(f"% of days with this type of {metric} ({days_mean}-day rolling mean)")

# %%
metric = "fatigue"
days_mean = 30
plot_categorical_rate(metric, days_mean, nan_is_no=False)

# %% [markdown]
# ### Pelvic pain: raw vs. inferred given pain medication

# %%
for days_window in [7, 28]:
    metrics = [
        "pelvic pain numeric",
        "pelvic_pain_inferred",
    ]

    fig, ax = plt.subplots(figsize=(12, 8))
    for metric in metrics:
        plt.plot(
            df[metric].rolling(f"{days_window}D").mean(),
            label=metric.replace("_", " ").replace(" numeric", ""),
        )
        fig.autofmt_xdate()

    plt.legend(title="Metric")
    plt.ylabel(f"{days_window}-day rolling mean")
    plt.title(f"{days_window}-day rolling mean")

# %%
def plot_timeline(
    metric: str,
    days_window: int,
    only_valid_cycles: bool,
):
    if only_valid_cycles:
        plot_data = df.loc[df["valid_cycle"]].copy()
    else:
        plot_data = df.copy()

    fig, ax = plt.subplots(figsize=(12, 8), facecolor="w")
    
    plt.plot(
        plot_data[metric].rolling(f"{days_window}D").mean(),
        label=metric.replace("_", " ").replace(" numeric", ""),
    )

    ## Peak day
    plotted_peak = False
    peak_days = plot_data.loc[plot_data["peak_day"] == True].index.values
    for peak_day in peak_days:
        # only make one legend label
        if plotted_peak:
            label = None
        else:
            label = "Peak Day"
            plotted_peak = True
        # approximate ovulation date, made a bit wider for visibility
        plt.axvspan(
            xmin=peak_day + np.timedelta64(-1,'D'),
            xmax=peak_day,
            color="royalblue",
            alpha=0.4,
            label=label,
        )

    ## Menstruation
    plotted_menstruation = False
    for cycle in plot_data["nth_cycle"].unique():
        if np.isnan(cycle):
            continue

        first_day_df = plot_data.loc[
            (plot_data["nth_cycle"] == cycle) &
            (plot_data["day of cycle"] == 1)
        ]

        last_day_df = plot_data.loc[
            (plot_data["nth_cycle"] == cycle) &
            plot_data["last_bleeding_day"]
        ]
        if first_day_df.empty or last_day_df.empty:
            continue
        first_day = first_day_df.index.values[0]
        last_day = last_day_df.index.values[0]

        # only make one legend label
        if plotted_menstruation:
            label = None
        else:
            label = "Menstruation"
            plotted_menstruation = True
        plt.axvspan(
            xmin=first_day,
            xmax=last_day,
            color="salmon",
            alpha=0.4,
            label=label,
        )

    fig.autofmt_xdate()

    plt.ylabel(f"{metric} {days_window}-day rolling mean")
    plt.title(f"{metric} {days_window}-day rolling mean")
    plt.legend(title="Metric/event")
    
    fig.savefig(
        f"{arguments['output_directory']}/{metric}_valid_only_{only_valid_cycles}.png",
    )

# %% [markdown]
# ### Superimpose menstruation and ovulation

# %%
for only_valid_cycles in [True]:
    plot_timeline(
        metric="pelvic_pain_inferred",
        days_window=7,
        only_valid_cycles=only_valid_cycles,
    )

# %% [markdown]
# ### Plot by cycle day, rather than by date

# %%
days_window = 3 # choose a small window to preserve information about the day

metrics = [
    "pelvic_pain_inferred",
    "fatigue_numeric",
    "headache_numeric",
]

# subset.sort_values(["day of cycle", "nth_cycle"], inplace=True)
indexed = subset.set_index("day of cycle")
indexed.sort_index(inplace=True)

fig, ax = plt.subplots(figsize=(12, 8))

for metric in metrics:
    # create a standardized metric, so we can compare many at once
    indexed[f"{metric}_standardized"] = (
        (indexed[metric] - indexed[metric].mean())
        / (2 * indexed[metric].std())
    )

    # Note: confidence intervals are likely too tight b/c of high correlation among similar days of cycle
    # TODO: fit ARIMA model
    sns.lineplot(
        x=indexed.index,
        y=indexed[f"{metric}_standardized"].rolling(window=days_window).mean(),
        ci=False,
        label=metric.replace("_", " ").replace(" numeric", ""),
    )

plt.xlabel("Day of Cycle")
plt.ylabel(f"{days_window}-day rolling mean")
plt.title(f"Standardized metrics by day of cycle, {days_window}-day mean")
plt.legend(title="Metric")
